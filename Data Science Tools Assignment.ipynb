# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nestor Borrero Perez**

# %% [markdown]
# Planning tehcnician

# %% [markdown]
# *As planning technician and data analyst I'm interested in going one step further and apply Machine Learning to my job. Would like to know how to achieve analysis of large sets of data, hoping to improve and deepen the scope of the data insights I use in my actual job.*

# %% [markdown]
# ### Code for printing the sum of two variables in string format

# %%
h= ("Hello")
f = ("fellow students.")
print( h+" "+f)
# Out:
# Hello fellow students.

# %% [markdown]
# 1. List of things to list:
#   * First thing on the list is just text
#   * link to Coursera: https://www.coursera.org/
#   * a table below:
# | Whatever      | Table         |
# | ------------- |:-------------:|
# | First cell    | first row     |
# | Second cell   | second row    |
# | Third cell    | third row     |
